# %%
import re
import time
import json
import urllib
import requests
from bs4 import BeautifulSoup as soup

# %%
link = "https://www.finam.ru/profile/mosbirzha-fyuchersy/lkoh/export/"
if True:
    r = requests.get(link)
    if r.status_code == 200:
        t = re.sub(r'\s', '', r.text)
        t = re.findall(r"Finam.IssuerProfile.Main.issue.*?</script>", t)
        t = re.findall(r'\{.*\}', t[0])[0]
        t = t.replace('false', 'False').replace('true', 'True').replace('null', 'None')
        exec('keys = ' + t)

# %%
kq = keys['quote']
code=kq['code'];
market=kq['market']['id']
em=kq['id'];
e='.csv';
p='3';
yf='2017';
yt='2017';
month_start='05';
day_start='20';
month_end='06';
day_end='20';
dtf='1';
tmf='1';
MSOR='1';
mstimever='0'
sep='1';
sep2='1';
datf='5';
at='1';


year_start=yf[2:];
year_end=yt[2:];
mf=(int(month_start.replace('0','')))-1;
mt=(int(month_end.replace('0','')))-1;
df=(int(day_start.replace('0','')))-1;
dt=(int(day_end.replace('0','')))-1;


def quotes(code,year_start,month_start,day_start,year_end,month_end,day_end,e,market,em,df,mf,yf,dt,mt,yt,p,dtf,tmf,MSOR,mstimever,sep,sep2,datf,at):
    
    page = urllib.request.urlopen('http://export.finam.ru/'+str(code)+'_'+str(year_start)+str(month_start)+str(day_start)+'_'+str(year_end)+str(month_end)+str(day_end)+str(e)+'?market='+str(market)+'&em='+str(em)+'&code='+str(code)+'&apply=0&df='+str(df)+'&mf='+str(mf)+'&yf='+str(yf)+'&from='+str(day_start)+'.'+str(month_start)+'.'+str(yf)+'&dt='+str(dt)+'&mt='+str(mt)+'&yt='+str(yt)+'&to='+str(day_end)+'.'+str(month_end)+'.'+str(yt)+'&p='+str(p)+'&f='+str(code)+'_'+str(year_start)+str(month_start)+str(day_start)+'_'+str(year_end)+str(month_end)+str(day_end)+'&e='+str(e)+'&cn='+str(code)+'&dtf='+str(dtf)+'&tmf='+str(tmf)+'&MSOR='+str(MSOR)+'&mstimever='+str(mstimever)+'&sep='+str(sep)+'&sep2='+str(sep2)+'&datf='+str(datf)+'&at='+str(at))
    f = open("company_quotes.csv", "wb")
    content = page.read()
    f.write(content)
    f.close()

qq = quotes(code,year_start,month_start,day_start,year_end,month_end,day_end,e,market,em,df,mf,yf,dt,mt,yt,p,dtf,tmf,MSOR,mstimever,sep,sep2,datf,at)

# %%
stocks = ['lkoh', 'vtbr', 'spfb-aflt', 'gold', 'gazp', 'sbrf']
years = [(str(y), str(y+1)) for y in range(1990, 2020)]

for stock in stocks:
    for timeframe in ['4', '7', '8']:
        f = open("./quotes/%s%s.csv" % (stock, timeframe), "w")
        f.write("<DATE>,<TIME>,<OPEN>,<HIGH>,<LOW>,<CLOSE>,<VOL>\n")
        f.close()
        for year in years:
            print(stock, timeframe, year)
            link = "https://www.finam.ru/profile/mosbirzha-fyuchersy/%s/export/" % stock
            r = requests.get(link)
            time.sleep(1)
            if r.status_code == 200:
                t = re.sub(r'\s', '', r.text)
                t = re.findall(r"Finam.IssuerProfile.Main.issue.*?</script>", t)
                t = re.findall(r'\{.*\}', t[0])[0]
                t = t.replace('false', 'False').replace('true', 'True').replace('null', 'None')
                exec('keys = ' + t)

                kq = keys['quote']
                code=kq['code'];
                market=kq['market']['id']
                em=kq['id'];
                e='.csv';
                p=timeframe;
                yf=year[0];
                yt=year[1];
                month_start='04';
                day_start='06';
                month_end='04';
                day_end='06';
                dtf='1';
                tmf='1';
                MSOR='1';
                mstimever='0'
                sep='1';
                sep2='1';
                datf='5';
                at='0';


                year_start=yf[2:];
                year_end=yt[2:];
                mf=(int(month_start.replace('0','')))-1;
                mt=(int(month_end.replace('0','')))-1;
                df=(int(day_start.replace('0','')))-1;
                dt=(int(day_end.replace('0','')))-1;


                def quotes(code,year_start,month_start,day_start,year_end,month_end,day_end,e,market,em,df,mf,yf,dt,mt,yt,p,dtf,tmf,MSOR,mstimever,sep,sep2,datf,at):

                    page = urllib.request.urlopen('http://export.finam.ru/'+str(code)+'_'+str(year_start)+str(month_start)+str(day_start)+'_'+str(year_end)+str(month_end)+str(day_end)+str(e)+'?market='+str(market)+'&em='+str(em)+'&code='+str(code)+'&apply=0&df='+str(df)+'&mf='+str(mf)+'&yf='+str(yf)+'&from='+str(day_start)+'.'+str(month_start)+'.'+str(yf)+'&dt='+str(dt)+'&mt='+str(mt)+'&yt='+str(yt)+'&to='+str(day_end)+'.'+str(month_end)+'.'+str(yt)+'&p='+str(p)+'&f='+str(code)+'_'+str(year_start)+str(month_start)+str(day_start)+'_'+str(year_end)+str(month_end)+str(day_end)+'&e='+str(e)+'&cn='+str(code)+'&dtf='+str(dtf)+'&tmf='+str(tmf)+'&MSOR='+str(MSOR)+'&mstimever='+str(mstimever)+'&sep='+str(sep)+'&sep2='+str(sep2)+'&datf='+str(datf)+'&at='+str(at))
                    f = open("./quotes/%s%s.csv" % (stock, timeframe), "ab")
                    content = page.read()
                    f.write(content)
                    f.close()
                    time.sleep(1)

                qq = quotes(code,year_start,month_start,day_start,year_end,month_end,day_end,e,market,em,df,mf,yf,dt,mt,yt,p,dtf,tmf,MSOR,mstimever,sep,sep2,datf,at)
# Out:
# lkoh 4 ('1990', '1991')
# lkoh 4 ('1991', '1992')
# lkoh 4 ('1992', '1993')
# lkoh 4 ('1993', '1994')
# lkoh 4 ('1994', '1995')
# lkoh 4 ('1995', '1996')
# lkoh 4 ('1996', '1997')
# lkoh 4 ('1997', '1998')
# lkoh 4 ('1998', '1999')
# lkoh 4 ('1999', '2000')
# lkoh 4 ('2000', '2001')
# lkoh 4 ('2001', '2002')
# lkoh 4 ('2002', '2003')
# lkoh 4 ('2003', '2004')
# lkoh 4 ('2004', '2005')
# lkoh 4 ('2005', '2006')
# lkoh 4 ('2006', '2007')
# lkoh 4 ('2007', '2008')
# lkoh 4 ('2008', '2009')
# lkoh 4 ('2009', '2010')
# lkoh 4 ('2010', '2011')
# lkoh 4 ('2011', '2012')
# lkoh 4 ('2012', '2013')
# lkoh 4 ('2013', '2014')
# lkoh 4 ('2014', '2015')
# lkoh 4 ('2015', '2016')
# lkoh 4 ('2016', '2017')
# lkoh 4 ('2017', '2018')
# lkoh 4 ('2018', '2019')
# lkoh 4 ('2019', '2020')
# lkoh 7 ('1990', '1991')
# lkoh 7 ('1991', '1992')
# lkoh 7 ('1992', '1993')
# lkoh 7 ('1993', '1994')
# lkoh 7 ('1994', '1995')
# lkoh 7 ('1995', '1996')
# lkoh 7 ('1996', '1997')
# lkoh 7 ('1997', '1998')
# lkoh 7 ('1998', '1999')
# lkoh 7 ('1999', '2000')
# lkoh 7 ('2000', '2001')
# lkoh 7 ('2001', '2002')
# lkoh 7 ('2002', '2003')
# lkoh 7 ('2003', '2004')
# lkoh 7 ('2004', '2005')
# lkoh 7 ('2005', '2006')
# lkoh 7 ('2006', '2007')
# lkoh 7 ('2007', '2008')
# lkoh 7 ('2008', '2009')
# lkoh 7 ('2009', '2010')
# lkoh 7 ('2010', '2011')
# lkoh 7 ('2011', '2012')
# lkoh 7 ('2012', '2013')
# lkoh 7 ('2013', '2014')
# lkoh 7 ('2014', '2015')
# lkoh 7 ('2015', '2016')
# lkoh 7 ('2016', '2017')
# lkoh 7 ('2017', '2018')
# lkoh 7 ('2018', '2019')
# lkoh 7 ('2019', '2020')
# lkoh 8 ('1990', '1991')
# lkoh 8 ('1991', '1992')
# lkoh 8 ('1992', '1993')
# lkoh 8 ('1993', '1994')
# lkoh 8 ('1994', '1995')
# lkoh 8 ('1995', '1996')
# lkoh 8 ('1996', '1997')
# lkoh 8 ('1997', '1998')
# lkoh 8 ('1998', '1999')
# lkoh 8 ('1999', '2000')
# lkoh 8 ('2000', '2001')
# lkoh 8 ('2001', '2002')
# lkoh 8 ('2002', '2003')
# lkoh 8 ('2003', '2004')
# lkoh 8 ('2004', '2005')
# lkoh 8 ('2005', '2006')
# lkoh 8 ('2006', '2007')
# lkoh 8 ('2007', '2008')
# lkoh 8 ('2008', '2009')
# lkoh 8 ('2009', '2010')
# lkoh 8 ('2010', '2011')
# lkoh 8 ('2011', '2012')
# lkoh 8 ('2012', '2013')
# lkoh 8 ('2013', '2014')
# lkoh 8 ('2014', '2015')
# lkoh 8 ('2015', '2016')
# lkoh 8 ('2016', '2017')
# lkoh 8 ('2017', '2018')
# lkoh 8 ('2018', '2019')
# lkoh 8 ('2019', '2020')
# vtbr 4 ('1990', '1991')
# vtbr 4 ('1991', '1992')
# vtbr 4 ('1992', '1993')
# vtbr 4 ('1993', '1994')
# vtbr 4 ('1994', '1995')
# vtbr 4 ('1995', '1996')
# vtbr 4 ('1996', '1997')
# vtbr 4 ('1997', '1998')
# vtbr 4 ('1998', '1999')
# vtbr 4 ('1999', '2000')
# vtbr 4 ('2000', '2001')
# vtbr 4 ('2001', '2002')
# vtbr 4 ('2002', '2003')
# vtbr 4 ('2003', '2004')
# vtbr 4 ('2004', '2005')
# vtbr 4 ('2005', '2006')
# vtbr 4 ('2006', '2007')
# vtbr 4 ('2007', '2008')
# vtbr 4 ('2008', '2009')
# vtbr 4 ('2009', '2010')
# vtbr 4 ('2010', '2011')
# vtbr 4 ('2011', '2012')
# vtbr 4 ('2012', '2013')
# vtbr 4 ('2013', '2014')
# vtbr 4 ('2014', '2015')
# vtbr 4 ('2015', '2016')
# vtbr 4 ('2016', '2017')
# vtbr 4 ('2017', '2018')
# vtbr 4 ('2018', '2019')
# vtbr 4 ('2019', '2020')
# vtbr 7 ('1990', '1991')
# vtbr 7 ('1991', '1992')
# vtbr 7 ('1992', '1993')
# vtbr 7 ('1993', '1994')
# vtbr 7 ('1994', '1995')
# vtbr 7 ('1995', '1996')
# vtbr 7 ('1996', '1997')
# vtbr 7 ('1997', '1998')
# vtbr 7 ('1998', '1999')
# vtbr 7 ('1999', '2000')
# vtbr 7 ('2000', '2001')
# vtbr 7 ('2001', '2002')
# vtbr 7 ('2002', '2003')
# vtbr 7 ('2003', '2004')
# vtbr 7 ('2004', '2005')
# vtbr 7 ('2005', '2006')
# vtbr 7 ('2006', '2007')
# vtbr 7 ('2007', '2008')
# vtbr 7 ('2008', '2009')
# vtbr 7 ('2009', '2010')
# vtbr 7 ('2010', '2011')
# vtbr 7 ('2011', '2012')
# vtbr 7 ('2012', '2013')
# vtbr 7 ('2013', '2014')
# vtbr 7 ('2014', '2015')
# vtbr 7 ('2015', '2016')
# vtbr 7 ('2016', '2017')
# vtbr 7 ('2017', '2018')
# vtbr 7 ('2018', '2019')
# vtbr 7 ('2019', '2020')
# vtbr 8 ('1990', '1991')
# vtbr 8 ('1991', '1992')
# vtbr 8 ('1992', '1993')
# vtbr 8 ('1993', '1994')
# vtbr 8 ('1994', '1995')
# vtbr 8 ('1995', '1996')
# vtbr 8 ('1996', '1997')
# vtbr 8 ('1997', '1998')
# vtbr 8 ('1998', '1999')
# vtbr 8 ('1999', '2000')
# vtbr 8 ('2000', '2001')
# vtbr 8 ('2001', '2002')
# vtbr 8 ('2002', '2003')
# vtbr 8 ('2003', '2004')
# vtbr 8 ('2004', '2005')
# vtbr 8 ('2005', '2006')
# vtbr 8 ('2006', '2007')
# vtbr 8 ('2007', '2008')
# vtbr 8 ('2008', '2009')
# vtbr 8 ('2009', '2010')
# vtbr 8 ('2010', '2011')
# vtbr 8 ('2011', '2012')
# vtbr 8 ('2012', '2013')
# vtbr 8 ('2013', '2014')
# vtbr 8 ('2014', '2015')
# vtbr 8 ('2015', '2016')
# vtbr 8 ('2016', '2017')
# vtbr 8 ('2017', '2018')
# vtbr 8 ('2018', '2019')
# vtbr 8 ('2019', '2020')
# spfb-aflt 4 ('1990', '1991')
# spfb-aflt 4 ('1991', '1992')
# spfb-aflt 4 ('1992', '1993')
# spfb-aflt 4 ('1993', '1994')
# spfb-aflt 4 ('1994', '1995')
# spfb-aflt 4 ('1995', '1996')
# spfb-aflt 4 ('1996', '1997')
# spfb-aflt 4 ('1997', '1998')
# spfb-aflt 4 ('1998', '1999')
# spfb-aflt 4 ('1999', '2000')
# spfb-aflt 4 ('2000', '2001')
# spfb-aflt 4 ('2001', '2002')
# spfb-aflt 4 ('2002', '2003')
# spfb-aflt 4 ('2003', '2004')
# spfb-aflt 4 ('2004', '2005')
# spfb-aflt 4 ('2005', '2006')
# spfb-aflt 4 ('2006', '2007')
# spfb-aflt 4 ('2007', '2008')
# spfb-aflt 4 ('2008', '2009')
# spfb-aflt 4 ('2009', '2010')
# spfb-aflt 4 ('2010', '2011')
# spfb-aflt 4 ('2011', '2012')
# spfb-aflt 4 ('2012', '2013')
# spfb-aflt 4 ('2013', '2014')
# spfb-aflt 4 ('2014', '2015')
# spfb-aflt 4 ('2015', '2016')
# spfb-aflt 4 ('2016', '2017')
# spfb-aflt 4 ('2017', '2018')
# spfb-aflt 4 ('2018', '2019')
# spfb-aflt 4 ('2019', '2020')
# spfb-aflt 7 ('1990', '1991')
# spfb-aflt 7 ('1991', '1992')
# spfb-aflt 7 ('1992', '1993')
# spfb-aflt 7 ('1993', '1994')
# spfb-aflt 7 ('1994', '1995')
# spfb-aflt 7 ('1995', '1996')
# spfb-aflt 7 ('1996', '1997')
# spfb-aflt 7 ('1997', '1998')
# spfb-aflt 7 ('1998', '1999')
# spfb-aflt 7 ('1999', '2000')
# spfb-aflt 7 ('2000', '2001')
# spfb-aflt 7 ('2001', '2002')
# spfb-aflt 7 ('2002', '2003')
# spfb-aflt 7 ('2003', '2004')
# spfb-aflt 7 ('2004', '2005')
# spfb-aflt 7 ('2005', '2006')
# spfb-aflt 7 ('2006', '2007')
# spfb-aflt 7 ('2007', '2008')
# spfb-aflt 7 ('2008', '2009')
# spfb-aflt 7 ('2009', '2010')
# spfb-aflt 7 ('2010', '2011')
# spfb-aflt 7 ('2011', '2012')
# spfb-aflt 7 ('2012', '2013')
# spfb-aflt 7 ('2013', '2014')
# spfb-aflt 7 ('2014', '2015')
# spfb-aflt 7 ('2015', '2016')
# spfb-aflt 7 ('2016', '2017')
# spfb-aflt 7 ('2017', '2018')
# spfb-aflt 7 ('2018', '2019')
# spfb-aflt 7 ('2019', '2020')
# spfb-aflt 8 ('1990', '1991')
# spfb-aflt 8 ('1991', '1992')
# spfb-aflt 8 ('1992', '1993')
# spfb-aflt 8 ('1993', '1994')
# spfb-aflt 8 ('1994', '1995')
# spfb-aflt 8 ('1995', '1996')
# spfb-aflt 8 ('1996', '1997')
# spfb-aflt 8 ('1997', '1998')
# spfb-aflt 8 ('1998', '1999')
# spfb-aflt 8 ('1999', '2000')
# spfb-aflt 8 ('2000', '2001')
# spfb-aflt 8 ('2001', '2002')
# spfb-aflt 8 ('2002', '2003')
# spfb-aflt 8 ('2003', '2004')
# spfb-aflt 8 ('2004', '2005')
# spfb-aflt 8 ('2005', '2006')
# spfb-aflt 8 ('2006', '2007')
# spfb-aflt 8 ('2007', '2008')
# spfb-aflt 8 ('2008', '2009')
# spfb-aflt 8 ('2009', '2010')
# spfb-aflt 8 ('2010', '2011')
# spfb-aflt 8 ('2011', '2012')
# spfb-aflt 8 ('2012', '2013')
# spfb-aflt 8 ('2013', '2014')
# spfb-aflt 8 ('2014', '2015')
# spfb-aflt 8 ('2015', '2016')
# spfb-aflt 8 ('2016', '2017')
# spfb-aflt 8 ('2017', '2018')
# spfb-aflt 8 ('2018', '2019')
# spfb-aflt 8 ('2019', '2020')
# gold 4 ('1990', '1991')
# gold 4 ('1991', '1992')
# gold 4 ('1992', '1993')
# gold 4 ('1993', '1994')
# gold 4 ('1994', '1995')
# gold 4 ('1995', '1996')
# gold 4 ('1996', '1997')
# gold 4 ('1997', '1998')
# gold 4 ('1998', '1999')
# gold 4 ('1999', '2000')
# gold 4 ('2000', '2001')
# gold 4 ('2001', '2002')
# gold 4 ('2002', '2003')
# gold 4 ('2003', '2004')
# gold 4 ('2004', '2005')
# gold 4 ('2005', '2006')
# gold 4 ('2006', '2007')
# gold 4 ('2007', '2008')
# gold 4 ('2008', '2009')
# gold 4 ('2009', '2010')
# gold 4 ('2010', '2011')
# gold 4 ('2011', '2012')
# gold 4 ('2012', '2013')
# gold 4 ('2013', '2014')
# gold 4 ('2014', '2015')
# gold 4 ('2015', '2016')
# gold 4 ('2016', '2017')
# gold 4 ('2017', '2018')
# gold 4 ('2018', '2019')
# gold 4 ('2019', '2020')
# gold 7 ('1990', '1991')
# gold 7 ('1991', '1992')
# gold 7 ('1992', '1993')
# gold 7 ('1993', '1994')
# gold 7 ('1994', '1995')
# gold 7 ('1995', '1996')
# gold 7 ('1996', '1997')
# gold 7 ('1997', '1998')
# gold 7 ('1998', '1999')
# gold 7 ('1999', '2000')
# gold 7 ('2000', '2001')
# gold 7 ('2001', '2002')
# gold 7 ('2002', '2003')
# gold 7 ('2003', '2004')
# gold 7 ('2004', '2005')
# gold 7 ('2005', '2006')
# gold 7 ('2006', '2007')
# gold 7 ('2007', '2008')
# gold 7 ('2008', '2009')
# gold 7 ('2009', '2010')
# gold 7 ('2010', '2011')
# gold 7 ('2011', '2012')
# gold 7 ('2012', '2013')
# gold 7 ('2013', '2014')
# gold 7 ('2014', '2015')
# gold 7 ('2015', '2016')
# gold 7 ('2016', '2017')
# gold 7 ('2017', '2018')
# gold 7 ('2018', '2019')
# gold 7 ('2019', '2020')
# gold 8 ('1990', '1991')
# gold 8 ('1991', '1992')
# gold 8 ('1992', '1993')
# gold 8 ('1993', '1994')
# gold 8 ('1994', '1995')
# gold 8 ('1995', '1996')
# gold 8 ('1996', '1997')
# gold 8 ('1997', '1998')
# gold 8 ('1998', '1999')
# gold 8 ('1999', '2000')
# gold 8 ('2000', '2001')
# gold 8 ('2001', '2002')
# gold 8 ('2002', '2003')
# gold 8 ('2003', '2004')
# gold 8 ('2004', '2005')
# gold 8 ('2005', '2006')
# gold 8 ('2006', '2007')
# gold 8 ('2007', '2008')
# gold 8 ('2008', '2009')
# gold 8 ('2009', '2010')
# gold 8 ('2010', '2011')
# gold 8 ('2011', '2012')
# gold 8 ('2012', '2013')
# gold 8 ('2013', '2014')
# gold 8 ('2014', '2015')
# gold 8 ('2015', '2016')
# gold 8 ('2016', '2017')
# gold 8 ('2017', '2018')
# gold 8 ('2018', '2019')
# gold 8 ('2019', '2020')
# gazp 4 ('1990', '1991')
# gazp 4 ('1991', '1992')
# gazp 4 ('1992', '1993')
# gazp 4 ('1993', '1994')
# gazp 4 ('1994', '1995')
# gazp 4 ('1995', '1996')
# gazp 4 ('1996', '1997')
# gazp 4 ('1997', '1998')
# gazp 4 ('1998', '1999')
# gazp 4 ('1999', '2000')
# gazp 4 ('2000', '2001')
# gazp 4 ('2001', '2002')
# gazp 4 ('2002', '2003')
# gazp 4 ('2003', '2004')
# gazp 4 ('2004', '2005')
# gazp 4 ('2005', '2006')
# gazp 4 ('2006', '2007')
# gazp 4 ('2007', '2008')
# gazp 4 ('2008', '2009')
# gazp 4 ('2009', '2010')
# gazp 4 ('2010', '2011')
# gazp 4 ('2011', '2012')
# gazp 4 ('2012', '2013')
# gazp 4 ('2013', '2014')
# gazp 4 ('2014', '2015')
# gazp 4 ('2015', '2016')
# gazp 4 ('2016', '2017')
# gazp 4 ('2017', '2018')
# gazp 4 ('2018', '2019')
# gazp 4 ('2019', '2020')
# gazp 7 ('1990', '1991')
# gazp 7 ('1991', '1992')
# gazp 7 ('1992', '1993')
# gazp 7 ('1993', '1994')
# gazp 7 ('1994', '1995')
# gazp 7 ('1995', '1996')
# gazp 7 ('1996', '1997')
# gazp 7 ('1997', '1998')
# gazp 7 ('1998', '1999')
# gazp 7 ('1999', '2000')
# gazp 7 ('2000', '2001')
# gazp 7 ('2001', '2002')
# gazp 7 ('2002', '2003')
# gazp 7 ('2003', '2004')
# gazp 7 ('2004', '2005')
# gazp 7 ('2005', '2006')
# gazp 7 ('2006', '2007')
# gazp 7 ('2007', '2008')
# gazp 7 ('2008', '2009')
# gazp 7 ('2009', '2010')
# gazp 7 ('2010', '2011')
# gazp 7 ('2011', '2012')
# gazp 7 ('2012', '2013')
# gazp 7 ('2013', '2014')
# gazp 7 ('2014', '2015')
# gazp 7 ('2015', '2016')
# gazp 7 ('2016', '2017')
# gazp 7 ('2017', '2018')
# gazp 7 ('2018', '2019')
# gazp 7 ('2019', '2020')
# gazp 8 ('1990', '1991')
# gazp 8 ('1991', '1992')
# gazp 8 ('1992', '1993')
# gazp 8 ('1993', '1994')
# gazp 8 ('1994', '1995')
# gazp 8 ('1995', '1996')
# gazp 8 ('1996', '1997')
# gazp 8 ('1997', '1998')
# gazp 8 ('1998', '1999')
# gazp 8 ('1999', '2000')
# gazp 8 ('2000', '2001')
# gazp 8 ('2001', '2002')
# gazp 8 ('2002', '2003')
# gazp 8 ('2003', '2004')
# gazp 8 ('2004', '2005')
# gazp 8 ('2005', '2006')
# gazp 8 ('2006', '2007')
# gazp 8 ('2007', '2008')
# gazp 8 ('2008', '2009')
# gazp 8 ('2009', '2010')
# gazp 8 ('2010', '2011')
# gazp 8 ('2011', '2012')
# gazp 8 ('2012', '2013')
# gazp 8 ('2013', '2014')
# gazp 8 ('2014', '2015')
# gazp 8 ('2015', '2016')
# gazp 8 ('2016', '2017')
# gazp 8 ('2017', '2018')
# gazp 8 ('2018', '2019')
# gazp 8 ('2019', '2020')
# sbrf 4 ('1990', '1991')
# sbrf 4 ('1991', '1992')
# sbrf 4 ('1992', '1993')
# sbrf 4 ('1993', '1994')
# sbrf 4 ('1994', '1995')
# sbrf 4 ('1995', '1996')
# sbrf 4 ('1996', '1997')
# sbrf 4 ('1997', '1998')
# sbrf 4 ('1998', '1999')
# sbrf 4 ('1999', '2000')
# sbrf 4 ('2000', '2001')
# sbrf 4 ('2001', '2002')
# sbrf 4 ('2002', '2003')
# sbrf 4 ('2003', '2004')
# sbrf 4 ('2004', '2005')
# sbrf 4 ('2005', '2006')
# sbrf 4 ('2006', '2007')
# sbrf 4 ('2007', '2008')
# sbrf 4 ('2008', '2009')
# sbrf 4 ('2009', '2010')
# sbrf 4 ('2010', '2011')
# sbrf 4 ('2011', '2012')
# sbrf 4 ('2012', '2013')
# sbrf 4 ('2013', '2014')
# sbrf 4 ('2014', '2015')
# sbrf 4 ('2015', '2016')
# sbrf 4 ('2016', '2017')
# sbrf 4 ('2017', '2018')
# sbrf 4 ('2018', '2019')
# sbrf 4 ('2019', '2020')
# sbrf 7 ('1990', '1991')
# sbrf 7 ('1991', '1992')
# sbrf 7 ('1992', '1993')
# sbrf 7 ('1993', '1994')
# sbrf 7 ('1994', '1995')
# sbrf 7 ('1995', '1996')
# sbrf 7 ('1996', '1997')
# sbrf 7 ('1997', '1998')
# sbrf 7 ('1998', '1999')
# sbrf 7 ('1999', '2000')
# sbrf 7 ('2000', '2001')
# sbrf 7 ('2001', '2002')
# sbrf 7 ('2002', '2003')
# sbrf 7 ('2003', '2004')
# sbrf 7 ('2004', '2005')
# sbrf 7 ('2005', '2006')
# sbrf 7 ('2006', '2007')
# sbrf 7 ('2007', '2008')
# sbrf 7 ('2008', '2009')
# sbrf 7 ('2009', '2010')
# sbrf 7 ('2010', '2011')
# sbrf 7 ('2011', '2012')
# sbrf 7 ('2012', '2013')
# sbrf 7 ('2013', '2014')
# sbrf 7 ('2014', '2015')
# sbrf 7 ('2015', '2016')
# sbrf 7 ('2016', '2017')
# sbrf 7 ('2017', '2018')
# sbrf 7 ('2018', '2019')
# sbrf 7 ('2019', '2020')
# sbrf 8 ('1990', '1991')
# sbrf 8 ('1991', '1992')
# sbrf 8 ('1992', '1993')
# sbrf 8 ('1993', '1994')
# sbrf 8 ('1994', '1995')
# sbrf 8 ('1995', '1996')
# sbrf 8 ('1996', '1997')
# sbrf 8 ('1997', '1998')
# sbrf 8 ('1998', '1999')
# sbrf 8 ('1999', '2000')
# sbrf 8 ('2000', '2001')
# sbrf 8 ('2001', '2002')
# sbrf 8 ('2002', '2003')
# sbrf 8 ('2003', '2004')
# sbrf 8 ('2004', '2005')
# sbrf 8 ('2005', '2006')
# sbrf 8 ('2006', '2007')
# sbrf 8 ('2007', '2008')
# sbrf 8 ('2008', '2009')
# sbrf 8 ('2009', '2010')
# sbrf 8 ('2010', '2011')
# sbrf 8 ('2011', '2012')
# sbrf 8 ('2012', '2013')
# sbrf 8 ('2013', '2014')
# sbrf 8 ('2014', '2015')
# sbrf 8 ('2015', '2016')
# sbrf 8 ('2016', '2017')
# sbrf 8 ('2017', '2018')
# sbrf 8 ('2018', '2019')
# sbrf 8 ('2019', '2020')
