# %%
import abc
import threading
import time
import pandas as pd
import numpy as np
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential, model_from_json, load_model, save_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from alpaca_trade_api import REST

# %%
# %pip install bottle
# Out:
# Collecting bottle
#   Downloading https://files.pythonhosted.org/packages/e9/39/2bf3a1fd963e749cdbe5036a184eda8c37d8af25d1297d94b8b7aeec17c4/bottle-0.12.18-py3-none-any.whl (89kB)
# Installing collected packages: bottle
# Successfully installed bottle-0.12.18
# Note: you may need to restart the kernel to use updated packages.

# %%
class AlpacaPaperSocket(REST):
    def __init__(self):
        super().__init__(
            key_id='PKE4YFUPUJXT4RI2JT8O',
            secret_key='Tsmc105gRWmtboD3lR9N0ts11pH4lCl3ryFBntYS',
            base_url='https://paper-api.alpaca.markets'
        )

# %%
class TradingSystem(abc.ABC):

    def __init__(self, api, symbol, time_frame, system_id, system_label):
        # Connect to api
        # Connect to BrokenPipeError
        # Save fields to class
        self.api = api
        self.symbol = symbol
        self.time_frame = time_frame
        self.system_id = system_id
        self.system_label = system_label
        thread = threading.Thread(target=self.system_loop)
        thread.start()

    @abc.abstractmethod
    def place_buy_order(self):
        pass

    @abc.abstractmethod
    def place_sell_order(self):
        pass

    @abc.abstractmethod
    def system_loop(self):
        pass

# %%
aps = AlpacaPaperSocket()

# %%
aps.submit_order()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-1ca4d277b6a5> in <module>
# ----> 1 aps.submit_order()
#
# TypeError: submit_order() missing 5 required positional arguments: 'symbol', 'qty', 'side', 'type', and 'time_in_force'

# %%
class PortfolioManagementSystem(TradingSystem):

    def __init__(self):
        super().__init__(AlpacaPaperSocket(), 'IBM', 6048000, 1, 'AI_PM')

    def place_buy_order(self):
        pass

    def place_sell_order(self):
        pass

    def system_loop(self):
        pass

# %%
Activation ='tanh'

# Class to develop your AI portfolio manager
class AIPMDevelopment:

    def __init__(self):
        # Read your data in and split the dependent and independent
        data = pd.read_csv('IBM1.csv')
        #data = self
        X = data['Delta Close']
        y = data.drop(['Delta Close'], axis=1)

        # Train test spit
        X_train, X_test, y_train, y_test = train_test_split(X, y)

        # Create the sequential
        network = Sequential()

        # Create the structure of the neural network
        network.add(Dense(1, input_shape=(1,), activation=Activation))
        network.add(Dense(3, activation=Activation))
        network.add(Dense(3, activation=Activation))
        network.add(Dense(3, activation=Activation))
        network.add(Dense(1, activation=Activation))

        # Compile the model
        network.compile(
                      optimizer='rmsprop',
                      loss='hinge',
                      metrics=['accuracy']
                      )
        # Train the model
        network.fit(X_train.values, y_train.values, epochs=100)

        # Evaluate the predictions of the model
        y_pred = network.predict(X_test.values)
        y_pred = np.around(y_pred, 0)
        print(classification_report(y_test, y_pred))

        # Save structure to json
        #model = network.to_json()
        #with open("model.json", "w") as json_file:
        #    json_file.write(model)

        # Save weights to HDF5
        save_model(network, "weights.h5")

AIPMDevelopment()
# Out:
# Epoch 1/100
# 195/195 [==============================] - 1s 5ms/sample - loss: 1.0280 - acc: 0.2667
# Epoch 2/100
# 195/195 [==============================] - 0s 497us/sample - loss: 1.0040 - acc: 0.2667
# Epoch 3/100
# 195/195 [==============================] - 0s 487us/sample - loss: 0.9855 - acc: 0.2667
# Epoch 4/100
# 195/195 [==============================] - 0s 425us/sample - loss: 0.9622 - acc: 0.2667
# Epoch 5/100
#               precision    recall  f1-score   support
#
#           -1       0.83      1.00      0.91        29
#            0       1.00      0.18      0.30        17
#            1       0.71      1.00      0.83        20
#
#     accuracy                           0.79        66
#    macro avg       0.85      0.73      0.68        66
# weighted avg       0.84      0.79      0.73        66

# %%
data_req
# Out:
#                                IBM
#                               open     high      low    close volume
# time
# 2020-02-27 09:45:00-05:00  136.600  136.600  136.490  136.495    982
# 2020-02-27 09:46:00-05:00  136.340  136.340  136.330  136.330    200
# 2020-02-27 09:47:00-05:00  136.360  136.410  136.280  136.280    104
# 2020-02-27 09:48:00-05:00  136.185  136.660  136.185  136.610   1100
# 2020-02-27 09:49:00-05:00  136.740  136.860  136.670  136.780   1103
# ...                            ...      ...      ...      ...    ...
# 2020-03-02 15:53:00-05:00  133.240  133.615  133.240  133.615   1345
# 2020-03-02 15:54:00-05:00  133.630  133.970  133.550  133.970   1499
# 2020-03-02 15:56:00-05:00  133.840  133.870  133.690  133.690   1424
# 2020-03-02 15:57:00-05:00  133.670  134.190  133.670  134.190   2536
# 2020-03-02 15:59:00-05:00  134.255  134.390  134.020  134.350   1898
#
# [1000 rows x 5 columns]

# %%
# AI Portfolio Manager
class PortfolioManagementModel:

    def __init__(self):
        # Data in to test that the saving of weights worked
        data = pd.read_csv('IBM.csv')
        X = data['Delta Close']
        y = data.drop(['Delta Close'], axis=1)

        # Read structure from json
        """json_file = open('model.json', 'r')
        json = json_file.read()
        json_file.close()
        self.network = model_from_json(json)"""

        # Read weights from HDF5
        self.network = load_model("weights.h5")

        # Verify weights and structure are loaded
        y_pred = self.network.predict(X.values)
        y_pred = np.around(y_pred, 0)
        print(classification_report(y, y_pred))
        print(self.network.evaluate(y, y_pred))

PortfolioManagementModel()
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.76      1.00      0.86        95
#            0       1.00      0.12      0.21        69
#            1       0.76      1.00      0.86        97
#
#     accuracy                           0.77       261
#    macro avg       0.84      0.71      0.64       261
# weighted avg       0.82      0.77      0.69       261
#
# 261/261 [==============================] - 0s 611us/sample - loss: 1.7347 - acc: 0.0307
# [1.7346997603602794, 0.03065134]

# %%
class PortfolioManagementSystem(TradingSystem):

    def __init__(self):
        super().__init__(AlpacaPaperSocket(), 'IBM', 86400, 1, 'AI_PM')
        self.AI = PortfolioManagementModel()

    def place_buy_order(self):
        self.api.submit_order(
                        symbol='IBM',
                        qty=1,
                        side='buy',
                        type='market',
                        time_in_force='day',
                    )

    def place_sell_order(self):
        self.api.submit_order(
                        symbol='IBM',
                        qty=1,
                        side='sell',
                        type='market',
                        time_in_force='day',
                    )

    def system_loop(self):
        # Variables for weekly close
        this_weeks_close = 0
        last_weeks_close = 0
        delta = 0
        day_count = 0
        while(True):
            # Wait a day to request more data
            time.sleep(1440)
            # Request EoD data for IBM
            data_req = self.api.get_barset('IBM', timeframe='1D', limit=1).df
            # Construct dataframe to predict
            x = pd.DataFrame(
                data=[[
                    data_req['IBM']['close'][0]]], columns='Close'.split()
            )
            if(day_count == 7):
                day_count = 0
                last_weeks_close = this_weeks_close
                this_weeks_close = x['Close']
                delta = this_weeks_close - last_weeks_close

                # AI choosing to buy, sell, or hold
                if np.around(self.AI.network.predict([delta])) <= -.5:
                    self.place_sell_order()

                elif np.around(self.AI.network.predict([delta]) >= .5):
                    self.place_buy_order()

PMSys = PortfolioManagementSystem()
PMSys.system_loop()
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.76      1.00      0.86        95
#            0       1.00      0.12      0.21        69
#            1       0.76      1.00      0.86        97
#
#     accuracy                           0.77       261
#    macro avg       0.84      0.71      0.64       261
# weighted avg       0.82      0.77      0.69       261
#
# 261/261 [==============================] - 0s 829us/sample - loss: 1.7347 - acc: 0.0307
# [1.7346997603602794, 0.03065134]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-430d81071fae> in <module>
#      53
#      54 PMSys = PortfolioManagementSystem()
# ---> 55 PMSys.system_loop()
#
# <ipython-input-20-430d81071fae> in system_loop(self)
#      31         while(True):
#      32             # Wait a day to request more data
# ---> 33             time.sleep(1440)
#      34             # Request EoD data for IBM
#      35             data_req = self.api.get_barset('IBM', timeframe='1D', limit=1).df
#
# KeyboardInterrupt:

# %%
data_req = PMSys.api.get_barset('IBM', timeframe='minute', limit=1000).df

# %%
data_req.to_csv('IBM1.csv')

# %%
data_req
# Out:
#                                IBM
#                               open     high      low    close volume
# time
# 2020-02-27 09:45:00-05:00  136.600  136.600  136.490  136.495    982
# 2020-02-27 09:46:00-05:00  136.340  136.340  136.330  136.330    200
# 2020-02-27 09:47:00-05:00  136.360  136.410  136.280  136.280    104
# 2020-02-27 09:48:00-05:00  136.185  136.660  136.185  136.610   1100
# 2020-02-27 09:49:00-05:00  136.740  136.860  136.670  136.780   1103
# ...                            ...      ...      ...      ...    ...
# 2020-03-02 15:53:00-05:00  133.240  133.615  133.240  133.615   1345
# 2020-03-02 15:54:00-05:00  133.630  133.970  133.550  133.970   1499
# 2020-03-02 15:56:00-05:00  133.840  133.870  133.690  133.690   1424
# 2020-03-02 15:57:00-05:00  133.670  134.190  133.670  134.190   2536
# 2020-03-02 15:59:00-05:00  134.255  134.390  134.020  134.350   1898
#
# [1000 rows x 5 columns]
# Exception in thread Thread-6:
# Traceback (most recent call last):
#   File "C:\Users\Admin\.conda\envs\neuro\lib\site-packages\urllib3\connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "C:\Users\Admin\.conda\envs\neuro\lib\site-packages\urllib3\connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "C:\Users\Admin\.conda\envs\neuro\lib\site-packages\urllib3\connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\Admin\.conda\envs\neuro\lib\http\client.py", line 1346, in getresponse
#     response.begin()
#   File "C:\Users\Admin\.conda\envs\neuro\lib\http\client.py", line 307, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\Admin\.conda\envs\neuro\lib\http\client.py", line 268, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\Admin\.conda\envs\neuro\lib\socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\Admin\.conda\envs\neuro\lib\ssl.py", line 1012, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\Admin\.conda\envs\neuro\lib\ssl.py", line 874, in read
#     return self._sslobj.read(len, buffer)
#   File "C:\Users\Admin\.conda\envs\neuro\lib\ssl.py", line 631, in read
#     v = self._sslobj.read(len, buffer)
# TimeoutError: [WinError 10060] Попытка установить соединение была безуспешной, т.к. от другого компьютера за требуемое время не получен нужный отклик, или было разорвано уже установленное соединение из-за неверного отклика уже подключенного компьютера
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Admin\.conda\envs\neuro\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\Admin\.conda\envs\neuro\lib\site-packages\urllib3\connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "C:\Users\Admin\.conda\envs\neuro\lib\site-packages\urllib3\util\retry.py", line 368, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\Admin\.conda\envs\neuro\lib\site-packages\urllib3\packages\six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\Admin\.conda\envs\neuro\lib\site-packages\urllib3\connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "C:\Users\Admin\.conda\envs\neuro\lib\site-packages\urllib3\connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "C:\Users\Admin\.conda\envs\neuro\lib\site-packages\urllib3\connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\Admin\.conda\envs\neuro\lib\http\client.py", line 1346, in getresponse
#     response.begin()
#   File "C:\Users\Admin\.conda\envs\neuro\lib\http\client.py", line 307, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\Admin\.conda\envs\neuro\lib\http\client.py", line 268, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\Admin\.conda\envs\neuro\lib\socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\Admin\.conda\envs\neuro\lib\ssl.py", line 1012, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\Admin\.conda\envs\neuro\lib\ssl.py", line 874, in read
#     return self._sslobj.read(len, buffer)
#   File "C:\Users\Admin\.conda\envs\neuro\lib\ssl.py", line 631, in read
#     v = self._sslobj.read(len, buffer)
# urllib3.exceptions.ProtocolError: ('Connection aborted.', TimeoutError(10060, 'Попытка установить соединение была безуспешной, т.к. от другого компьютера за требуемое время не получен нужный отклик, или было разорвано уже установленное соединение из-за неверного отклика уже подключенного компьютера', None, 10060, None))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Admin\.conda\envs\neuro\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\.conda\envs\neuro\lib\threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-9-f744439bcd95>", line 35, in system_loop
#     data_req = self.api.get_barset('IBM', timeframe='1D', limit=1).df
#   File "C:\Users\Admin\.conda\envs\neuro\lib\site-packages\alpaca_trade_api\rest.py", line 359, in get_barset
#     resp = self.data_get('/bars/{}'.format(timeframe), params)
#   File "C:\Users\Admin\.conda\envs\neuro\lib\site-packages\alpaca_trade_api\rest.py", line 166, in data_get
#     'GET', path, data, base_url=base_url, api_version='v1'
#   File "C:\Users\Admin\.conda\envs\neuro\lib\site-packages\alpaca_trade_api\rest.py", line 115, in _request
#     return self._one_request(method, url, opts, retry)
#   File "C:\Users\Admin\.conda\envs\neuro\lib\site-packages\alpaca_trade_api\rest.py", line 134, in _one_request
#     resp = self._session.request(method, url, **opts)
#   File "C:\Users\Admin\.conda\envs\neuro\lib\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\Admin\.conda\envs\neuro\lib\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\Admin\.conda\envs\neuro\lib\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', TimeoutError(10060, 'Попытка установить соединение была безуспешной, т.к. от другого компьютера за требуемое время не получен нужный отклик, или было разорвано уже установленное соединение из-за неверного отклика уже подключенного компьютера', None, 10060, None))

# %%
x = pd.DataFrame(
                data=[[
                    data_req['IBM']['close'][0]]], columns='Close'.split()
            )
x
# Out:
#     Close
# 0  132.87
